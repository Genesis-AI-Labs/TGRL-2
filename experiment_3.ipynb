# %%
# Cell 1: Imports
import gymnasium as gym
import numpy as np
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.results_plotter import ts2xy, load_results
from stable_baselines3.common.monitor import Monitor
import matplotlib.pyplot as plt
import os
from stable_baselines3.common.logger import configure

# %%
# Cell 2: Callback Definition
class RewardTrackerCallback(BaseCallback):
    """
    Callback for tracking rewards over training.
    Stores both episodic rewards and smoothed averages.
    """
    def __init__(self, verbose=0, check_freq=1000, window_size=100):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.window_size = window_size
        # Track both raw episode rewards and smoothed averages
        self.rewards = []
        self.smoothed_rewards = []
        self.episode_rewards = []
        self.timesteps = []
        
    def _on_step(self) -> bool:
        # Get current episode reward from the monitor
        if len(self.model.ep_info_buffer) > 0:
            latest_reward = self.model.ep_info_buffer[-1]["r"]
            self.episode_rewards.append(latest_reward)
        
        if self.n_calls % self.check_freq == 0:
            x, y = ts2xy(load_results(self.model.logger.dir), 'timesteps')
            if len(y) > 0:
                # Store raw rewards
                self.rewards.append(y[-1])
                # Store smoothed rewards
                if len(y) >= self.window_size:
                    smoothed_reward = np.mean(y[-self.window_size:])
                    self.smoothed_rewards.append(smoothed_reward)
                    self.timesteps.append(x[-1])
        return True

# %%
# Cell 3: Environment Creation
def create_env(env_id="LunarLander-v2", log_dir="./logs/"):
    """Create a monitored vectorized environment"""
    os.makedirs(log_dir, exist_ok=True)
    
    def make_env():
        env = gym.make(env_id)
        env = Monitor(env, log_dir)
        return env
    
    env = DummyVecEnv([make_env])
    env = VecMonitor(env)
    return env

# %%
# Cell 4: Training Function
def train_baseline(total_timesteps=1_000_000, seed=42):
    """
    Train a baseline PPO agent on LunarLander-v2
    """
    # Set up logging
    log_dir = "./logs/lunarlander_baseline/"
    os.makedirs(log_dir, exist_ok=True)
    
    # Create environment
    env = create_env(log_dir=log_dir)
    
    # Configure logger
    logger = configure(log_dir, ["stdout", "csv", "tensorboard"])
    
    # Create PPO model with standard hyperparameters for LunarLander
    model = PPO(
        "MlpPolicy",
        env,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        verbose=1,
        seed=seed
    )
    model.set_logger(logger)
    
    # Set up callback
    callback = RewardTrackerCallback(check_freq=10000, window_size=100)
    
    # Train the model
    model.learn(
        total_timesteps=total_timesteps,
        callback=callback
    )
    
    return model, callback

# %%
# Cell 5: Plotting Function
def plot_training_results(callback, title="PPO Baseline on LunarLander-v2"):
    """Plot training curves"""
    plt.figure(figsize=(10, 5))
    
    # Plot raw episode rewards with low alpha
    if len(callback.episode_rewards) > 0:
        episodes = np.arange(len(callback.episode_rewards))
        plt.plot(episodes, callback.episode_rewards, alpha=0.1, color='blue', label='Episode Rewards')
    
    # Plot smoothed rewards
    if len(callback.smoothed_rewards) > 0:
        plt.plot(callback.timesteps, callback.smoothed_rewards, 
                color='blue', linewidth=2, label='Smoothed Reward (100 ep)')
    
    plt.xlabel("Timesteps")
    plt.ylabel("Reward")
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Cell 6: Run Training
# You can adjust these parameters as needed
model, callback = train_baseline(total_timesteps=500_000)

# Cell 7: Plot Results
plot_training_results(callback)
# Out:
# Logging to ./logs/lunarlander_baseline/
# c:\Users\bunny\anaconda3\envs\gym\Lib\site-packages\stable_baselines3\common\vec_env\vec_monitor.py:44: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.7     |
# |    ep_rew_mean     | -153     |
# | time/              |          |
# |    fps             | 861      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.3         |
# |    ep_rew_mean          | -163         |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0072879726 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0054       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 308          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0039      |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008971721 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 484         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00509    |
# |    value_loss           | 912         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 690         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008087431 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00896    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 226         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 756         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -156        |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006589373 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.000332   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 458         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0086     |
# |    value_loss           | 973         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 677         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008737474 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -2.86e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 221         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 441         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 667         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010398308 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.000215    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 379         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 457         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 8           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012022152 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.0414     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 291         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 9           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008534236 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.0143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 221         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 537         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 10          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012719811 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.00462    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 90.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 292         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 11          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010555318 |
# |    clip_fraction        | 0.0868      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.0636     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 140         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 447         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006611174 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.0775      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00437    |
# |    value_loss           | 402         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -121         |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 13           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0073516113 |
# |    clip_fraction        | 0.0741       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.0268      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00973     |
# |    value_loss           | 262          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 163         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 14          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012274909 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 15          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007065174 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0653      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 141         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 302         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 186         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 16          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004264956 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.252       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 225         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 204        |
# |    ep_rew_mean          | -105       |
# | time/                   |            |
# |    fps                  | 539        |
# |    iterations           | 17         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00971158 |
# |    clip_fraction        | 0.0685     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.2        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 52.6       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0061    |
# |    value_loss           | 209        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 531         |
# |    iterations           | 18          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006444929 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 134         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 315         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | -101        |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 19          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005969664 |
# |    clip_fraction        | 0.0225      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -0.00829    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 308         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 20          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006127592 |
# |    clip_fraction        | 0.0192      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 390         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 255        |
# |    ep_rew_mean          | -103       |
# | time/                   |            |
# |    fps                  | 519        |
# |    iterations           | 21         |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00943482 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.564      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 83         |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00715   |
# |    value_loss           | 216        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 268         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 517         |
# |    iterations           | 22          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008383468 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00807    |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 285         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 23          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008614676 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 107         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 302      |
# |    ep_rew_mean          | -102     |
# | time/                   |          |
# |    fps                  | 514      |
# |    iterations           | 24       |
# |    time_elapsed         | 95       |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 0.012264 |
# |    clip_fraction        | 0.134    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.2     |
# |    explained_variance   | 0.849    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 12.1     |
# |    n_updates            | 230      |
# |    policy_gradient_loss | -0.0115  |
# |    value_loss           | 49       |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 324         |
# |    ep_rew_mean          | -97.5       |
# | time/                   |             |
# |    fps                  | 513         |
# |    iterations           | 25          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010462159 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 22.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 335         |
# |    ep_rew_mean          | -93.1       |
# | time/                   |             |
# |    fps                  | 515         |
# |    iterations           | 26          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010785403 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 72.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | -89.9        |
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 27           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0076390486 |
# |    clip_fraction        | 0.0968       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29           |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00776     |
# |    value_loss           | 85.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | -87.1       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 28          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009799957 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | -77.1       |
# | time/                   |             |
# |    fps                  | 509         |
# |    iterations           | 29          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010283538 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 46.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 395         |
# |    ep_rew_mean          | -71.3       |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 30          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006451502 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.4        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 154         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 413         |
# |    ep_rew_mean          | -65.9       |
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 31          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014475066 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 32.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | -62.4       |
# | time/                   |             |
# |    fps                  | 504         |
# |    iterations           | 32          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011168273 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00688    |
# |    value_loss           | 83          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 449         |
# |    ep_rew_mean          | -55.5       |
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 33          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012101879 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.859      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 466        |
# |    ep_rew_mean          | -49        |
# | time/                   |            |
# |    fps                  | 505        |
# |    iterations           | 34         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01486453 |
# |    clip_fraction        | 0.0996     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.879     |
# |    explained_variance   | 0.84       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.1       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00442   |
# |    value_loss           | 42.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | -48.3       |
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 35          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.021969393 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.99        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 9.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | -45.2       |
# | time/                   |             |
# |    fps                  | 503         |
# |    iterations           | 36          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008612486 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 11.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 489         |
# |    ep_rew_mean          | -41.2       |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 37          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010273399 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.1        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 501         |
# |    ep_rew_mean          | -42         |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 38          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011026423 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 6.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | -38.4       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 39          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007370179 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.95        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 33.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 533         |
# |    ep_rew_mean          | -39.5       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 40          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013882923 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00843    |
# |    value_loss           | 43.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 549          |
# |    ep_rew_mean          | -34.5        |
# | time/                   |              |
# |    fps                  | 499          |
# |    iterations           | 41           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0077544474 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.94        |
# |    explained_variance   | 0.681        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.11         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 40.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 557          |
# |    ep_rew_mean          | -33.9        |
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 42           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0070081344 |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.85         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00506     |
# |    value_loss           | 9            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 579         |
# |    ep_rew_mean          | -27.7       |
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 43          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008858121 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.02        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 592         |
# |    ep_rew_mean          | -20.7       |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 44          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014521011 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00635    |
# |    value_loss           | 49.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 600          |
# |    ep_rew_mean          | -12.8        |
# | time/                   |              |
# |    fps                  | 495          |
# |    iterations           | 45           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0060071833 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.732       |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 131          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 605         |
# |    ep_rew_mean          | -7.03       |
# | time/                   |             |
# |    fps                  | 493         |
# |    iterations           | 46          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008445902 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.6        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 150         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 618         |
# |    ep_rew_mean          | -2.83       |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 47          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005068641 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 203         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 629          |
# |    ep_rew_mean          | 8.19         |
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 48           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0038495106 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.709        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.6         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 54.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 635         |
# |    ep_rew_mean          | 20.8        |
# | time/                   |             |
# |    fps                  | 491         |
# |    iterations           | 49          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.003975326 |
# |    clip_fraction        | 0.0186      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 177         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | 30.7        |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 50          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006322602 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 657         |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 51          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.004220306 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.3        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00172    |
# |    value_loss           | 153         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 665          |
# |    ep_rew_mean          | 55           |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 52           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0050584497 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000396    |
# |    value_loss           | 95.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 679          |
# |    ep_rew_mean          | 65           |
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 53           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0028230096 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 64.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 683          |
# |    ep_rew_mean          | 69           |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 54           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0072173737 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.793       |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 108          |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00397     |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 682         |
# |    ep_rew_mean          | 81.4        |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 55          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# ...
# |    ep_rew_mean          | 215        |
# | time/                   |            |
# |    fps                  | 482        |
# |    iterations           | 228        |
# |    time_elapsed         | 967        |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.00702138 |
# |    clip_fraction        | 0.0576     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 68.6       |
# |    n_updates            | 2270       |
# |    policy_gradient_loss | -0.00238   |
# |    value_loss           | 129        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 273          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 229          |
# |    time_elapsed         | 972          |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 0.0054262965 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.6         |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 29.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 273          |
# |    ep_rew_mean          | 215          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 230          |
# |    time_elapsed         | 976          |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 0.0025919597 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.474       |
# |    explained_variance   | 0.798        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.1         |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 147          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 276          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 231          |
# |    time_elapsed         | 980          |
# |    total_timesteps      | 473088       |
# | train/                  |              |
# |    approx_kl            | 0.0036965916 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.862        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.4         |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 101          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 271         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 232         |
# |    time_elapsed         | 984         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.004508308 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.48       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00313    |
# |    value_loss           | 62.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 233         |
# |    time_elapsed         | 988         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.003854571 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 125         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 285          |
# |    ep_rew_mean          | 223          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 234          |
# |    time_elapsed         | 993          |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0044849743 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.349       |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 25.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 288          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 235          |
# |    time_elapsed         | 998          |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 0.0045318566 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.000855    |
# |    value_loss           | 33.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 290          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 236          |
# |    time_elapsed         | 1002         |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0028162166 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.5         |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 63.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 237         |
# |    time_elapsed         | 1006        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.003623101 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.97        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 77.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 238         |
# |    time_elapsed         | 1010        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.003256888 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.5        |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00543    |
# |    value_loss           | 315         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 284         |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 239         |
# |    time_elapsed         | 1014        |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.004771931 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00327    |
# |    value_loss           | 85.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 286          |
# |    ep_rew_mean          | 223          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 240          |
# |    time_elapsed         | 1019         |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0024810932 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.3         |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 91.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | 222          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 241          |
# |    time_elapsed         | 1023         |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 0.0049304515 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.1         |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 87.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 274          |
# |    ep_rew_mean          | 209          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 242          |
# |    time_elapsed         | 1027         |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0037092697 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.756        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.5         |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 229          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 271          |
# |    ep_rew_mean          | 205          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 243          |
# |    time_elapsed         | 1031         |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0070618675 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 188          |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 458          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 202          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 244          |
# |    time_elapsed         | 1035         |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0049647773 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.1         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 143          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 245          |
# |    time_elapsed         | 1040         |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0032487272 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.4         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 135          |
# ------------------------------------------
